# %%
import torch
import pandas as pd

predicted_2024 = torch.load("graph_embeddings/embeddings_2024.pt")

print("Predicted Embeddings Shape:", predicted_2024.shape)

predicted_df = pd.DataFrame(predicted_2024.detach().numpy(), columns=['rainfall', 'temperature'])

print("Sample Predictions for 2024:\n", predicted_df.head())

print("\nStatistics for 2024 Predictions:")
print(predicted_df.describe())
# Out:
# c:\Users\purav\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Predicted Embeddings Shape: torch.Size([5040, 2])
# Sample Predictions for 2024:
#     rainfall  temperature
# 0  4.155268    26.886507
# 1  5.142292    27.242908
# 2  5.349088    31.099161
# 3  5.850760    29.059217
# 4  6.264270    34.169796
#
# Statistics for 2024 Predictions:
#           rainfall  temperature
# count  5040.000000  5040.000000
# mean      3.092247    30.520725
# std       2.086364     4.498822
# min       0.119081     0.629953
# 25%       1.879005    29.657430
# 50%       2.657917    31.888131
# 75%       3.610111    32.766599
# max      21.644596    42.276035

# %%
import plotly.express as px
import pandas as pd
import torch

# Load predicted embeddings
predicted_2024 = torch.load("graph_embeddings/embeddings_2024.pt").detach().numpy()

# Load the original dataset for geographical information
data_2023 = pd.read_csv(r"C:\Users\purav\OneDrive\Desktop\Fi Year Project\Final-Year-Project\Data\Processed\climate_data.csv")
data_2023 = data_2023[data_2023['year'] == 2023].reset_index(drop=True)

# Add predictions to the DataFrame
data_2023['predicted_rainfall'] = predicted_2024[:, 0]
data_2023['predicted_temperature'] = predicted_2024[:, 1]

# Visualize Rainfall Predictions
fig_rainfall = px.scatter_mapbox(
    data_2023,
    lat='latitude',
    lon='longitude',
    color='predicted_rainfall',
    size='predicted_rainfall',
    color_continuous_scale='viridis',
    title='Predicted Rainfall for 2024',
    mapbox_style='carto-positron',
    zoom=4
)
fig_rainfall.show()

# Visualize Temperature Predictions
fig_temperature = px.scatter_mapbox(
    data_2023,
    lat='latitude',
    lon='longitude',
    color='predicted_temperature',
    size='predicted_temperature',
    color_continuous_scale='plasma',
    title='Predicted Temperature for 2024',
    mapbox_style='carto-positron',
    zoom=4
)
fig_temperature.show()

# %%
import torch
import pandas as pd

predicted_2027 = torch.load("graph_embeddings/embeddings_2027.pt")

print("Predicted Embeddings Shape:", predicted_2027.shape)

predicted_df = pd.DataFrame(predicted_2027.detach().numpy(), columns=['rainfall', 'temperature'])

print("Sample Predictions for 2027:\n", predicted_df.head())

print("\nStatistics for 2027 Predictions:")
print(predicted_df.describe())
# Out:
# c:\Users\purav\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Predicted Embeddings Shape: torch.Size([5040, 2])
# Sample Predictions for 2027:
#     rainfall  temperature
# 0  4.155268    26.886507
# 1  5.142292    27.242908
# 2  5.349088    31.099161
# 3  5.850760    29.059217
# 4  6.264270    34.169796
#
# Statistics for 2027 Predictions:
#           rainfall  temperature
# count  5040.000000  5040.000000
# mean      3.092247    30.520725
# std       2.086364     4.498822
# min       0.119081     0.629953
# 25%       1.879005    29.657430
# 50%       2.657917    31.888131
# 75%       3.610111    32.766599
# max      21.644596    42.276035
